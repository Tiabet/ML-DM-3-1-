# %%
import matplotlib.pyplot as plt

credit = [0.040111541748046875, 0.19858241081237793, 0.0861501693725586]
adult  = [0.29528331756591797, 2.373206853866577, 3.5202035903930664]
higgs = [0.46872830390930176, 2.0272743701934814, 9.841265439987183]
covertype = [8.525601148605347, 19.5908842086792, 183.84770441055298]
models = ['lgbm','catboost','xgboost']

plt.plot(models, credit, label='Credit')
plt.plot(models, adult, label='Adult')
plt.plot(models, higgs, label='Higgs')
plt.plot(models, covertype, label='Covertype')

plt.xlabel('Models')
plt.ylabel('Values')
plt.title('Graph of time costs of four dataset')

plt.legend()

plt.show()
